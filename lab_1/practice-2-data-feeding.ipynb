# %%
# I am done understanding the code and logics of this file.

# %%
import pandas as pd
import numpy as np
def load_and_clean_data(file_path):
    df = pd.read_csv(file_path)
    df = df.dropna() # Remove missing values
    df = df.reset_index(drop=True)
    print(df)
    return df

# %%
def calculate_statistics(df):
    return df.describe()
if __name__ == "__main__":
    print("This is my Cleaned Data file:")
    data = load_and_clean_data("data.csv")
    stats = calculate_statistics(data)
    print("\n""This is my Statistics file:")
    print(stats)
# Out:
# This is my Cleaned Data file:
#            Name Class  No    ID
# 0      Ali Khan   10A   1  1001
# 1    Sara Ahmed   10A   2  1002
# 2    John Smith   10B   3  1003
# 3   Maria Lopez   10B   4  1004
# 4  Ahmed Hassan   10C   5  1005
#
# This is my Statistics file:
#              No           ID
# count  5.000000     5.000000
# mean   3.000000  1003.000000
# std    1.581139     1.581139
# min    1.000000  1001.000000
# 25%    2.000000  1002.000000
# 50%    3.000000  1003.000000
# 75%    4.000000  1004.000000
# max    5.000000  1005.000000
